# %%
# import package
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\KULIAH\SEMESTER 5\MACHLEARN\Machine_Learning_2023\jobsheet3_regresion\prak1.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/d%3A/KULIAH/SEMESTER%205/MACHLEARN/Machine_Learning_2023/jobsheet3_regresion/prak1.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> # import package
# ----> <a href='vscode-notebook-cell:/d%3A/KULIAH/SEMESTER%205/MACHLEARN/Machine_Learning_2023/jobsheet3_regresion/prak1.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/d%3A/KULIAH/SEMESTER%205/MACHLEARN/Machine_Learning_2023/jobsheet3_regresion/prak1.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'numpy'
