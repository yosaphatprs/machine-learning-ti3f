# %% [markdown]
# # Nama      : Brian Mohamad Safiudin
# # NIM       : 2141720133
# # Kelas     : TI - 3F

# %% [markdown]
# ---
# ## **Deskripsi Tugas**
# ### Pada tugas pratikum ini Anda akan menggunakan data "Wisconsin Breast Cancer". Data tersebut terdiri dari 569 data yang digunakan untuk mendiagnonis jenis kanker Malignant (M) dan Benign (B). Tugas Anda adalah,
# ##### 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.
# ##### 2. Lakukan proses encoding pada kolom "diagnosis".
# ##### 3. Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.
# ##### 4. Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20.
# ---

# %% [markdown]
# # 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.
# ### **Variabel yang dapat digunakan:**
#
# ##### 1. id: Ini adalah variabel ID yang mungkin tidak relevan dalam analisis prediksi kanker payudara.
# ##### 2. diagnosis (target): Ini adalah variabel target yang berisi diagnosis (M atau B).
# ##### 3. radius_mean: Mean radius dari inti sel kanker.
# ##### 4. texture_mean: Mean tekstur dari inti sel kanker.
# ##### 5. perimeter_mean: Mean keliling dari inti sel kanker.
# ##### 6. area_mean: Mean luas dari inti sel kanker.
# ##### 7. smoothness_mean: Mean kehalusan dari inti sel kanker.
# ##### 8. compactness_mean: Mean kompakness dari inti sel kanker.
# ##### 9. concavity_mean: Mean konkavitas dari inti sel kanker.
# ##### 10. concave points_mean: Mean jumlah bagian cekung dari kontur inti sel kanker.
# ##### 11. symmetry_mean: Mean simetri dari inti sel kanker.
# ##### 12. fractal_dimension_mean: Mean dimensi fraktal dari inti sel kanker.
# ---
#
# ### **Variabel yang tidak dapat digunakan:**
#
# ##### 1. radius_se: Standar error dari radius inti sel kanker.
# ##### 2. texture_se: Standar error dari tekstur inti sel kanker.
# ##### 3. perimeter_se: Standar error dari keliling inti sel kanker.
# ##### 4. area_se: Standar error dari luas inti sel kanker.
# ##### 5. smoothness_se: Standar error dari kehalusan inti sel kanker.
# ##### 6. compactness_se: Standar error dari kompakness inti sel kanker.
# ##### 7. concavity_se: Standar error dari konkavitas inti sel kanker.
# ##### 8. concave points_se: Standar error dari jumlah bagian cekung dari kontur inti sel kanker.
# ##### 9. symmetry_se: Standar error dari simetri inti sel kanker.
# ##### 10. fractal_dimension_se: Standar error dari dimensi fraktal inti sel kanker.
# ##### 11. Variabel yang berakhir dengan "_worst" adalah rata-rata dari tiga nilai terbesar untuk masing-masing atribut, dan dapat digunakan dalam analisis jika diperlukan.

# %% [markdown]
# ---
# # 2. Lakukan proses encoding pada kolom "diagnosis".

# %%
import pandas as pd 
# cara untuk mengimpor (import) pustaka atau modul tertentu ke dalam kode Python

data = 'wbc.csv' # path dataset
df = pd.read_csv(data) # load dataset

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
le = LabelEncoder() # membuat objek dari LabelEncoder
df['diagnosis'] = le.fit_transform(df['diagnosis']) # proses encoding
# menggunakan LabelEncoder dari pustaka scikit-learn (sklearn) untuk mengkodekan kolom 'Sex' dan 'Cabin' dalam DataFrame df dari nilai kategorikal menjadi nilai numerik

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ---
# # 3. Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.

# %%
std = StandardScaler()
df['radius_mean'] = std.fit_transform(df[['radius_mean']])
df['texture_mean'] = std.fit_transform(df[['texture_mean']])
df['perimeter_mean'] = std.fit_transform(df[['perimeter_mean']])
df['area_mean'] = std.fit_transform(df[['area_mean']])

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1     1.097064     -2.073335        1.269934   0.984375
# 1    842517          1     1.829821     -0.353632        1.685955   1.908708
# 2  84300903          1     1.579888      0.456187        1.566503   1.558884
# 3  84348301          1    -0.768909      0.253732       -0.592687  -0.764464
# 4  84358402          1     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ##### > id tidak termasuk numerik karena sebagai identifikasi unik untuk setiap sampel data dan bukan representasi numerik dari suatu fitur atau atribut.

# %% [markdown]
# ---
# # 4. Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20

# %%
from sklearn.model_selection import train_test_split

# Split data training dan dan lainnya
# data lainnya, akan kita split lagi menjadi validasi dan testing.
# Rasio yang akan kita gunakan adalah 8:1:1
df_train, df_test = train_test_split(df, test_size=0.2, random_state=0, stratify=df['diagnosis'])

# Cek masing-masing ukuran data

print(f'Jumlah label data asli:\n{df.diagnosis.value_counts()}')
print(f'Jumlah label data train:\n{df_train.diagnosis.value_counts()}')
print(f'Jumlah label data test:\n{df_test.diagnosis.value_counts()}')
# Out:
# Jumlah label data asli:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64
# Jumlah label data train:
# 0    285
# 1    170
# Name: diagnosis, dtype: int64
# Jumlah label data test:
# 0    72
# 1    42
# Name: diagnosis, dtype: int64
