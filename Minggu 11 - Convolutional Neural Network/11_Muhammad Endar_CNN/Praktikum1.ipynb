# %% [markdown]
# ## **Jobsheet 11 | Pertemuan 11**
# ## **Convolutional Neural Network (CNN)**
#
# ---
#
# ### **Praktikum 1**
# Klasifikasi 🐱 dan 🐶<p>
#
# ### **Deskripsi**
# Pada praktikum ini kita akan membuat model klasifikasi CNN sederhana pada kasus citra kucing dan anjing.
#
# ### **Dataset**
# Dataset merupakan data citra anjing dan kucing yang telah dibagi menjadi data training dan data testing. Dikarenakan data cukup besar, pastikan koneksi Anda sebelum mengunduh dataset.
#
# **Download Dataset Terlebih Dahulu**<p>
# [DOWNLOAD(klik)](https://drive.google.com/file/d/1vYrqBI1VmiXXJd5sgtKK2nuQvC8T1ryb/view?usp=drive_link)
#
# ----
#
# ### **import tensorflow as tf**

# %%
#akses drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### **Langkah 2 - Pra Pengolahan Data**
# Pada tahap ini kita akan sedikit melakukan manipulasi pada citra yang digunakan. Manipulasi yang dilakukan diantaranya adalah normalisasi nilai piksel, koreksi kemiringan, pembesaran (zoom), dan flip.<p>
#
# **Langkah 2.1. Pra Pengolahan Data Training**

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/aset/dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8030 images belonging to 2 classes.

# %% [markdown]
# **Langkah 2.2. Pra Pengolahan Data Testing**

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/aset/dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ### **Langkah 3 - Pembuatan Model CNN**
#
# **Langkah 3.1.  - Inisiasi Model CNN**

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# **Langkah 3.2. - Pembuatan Layer Konvolusi 1**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# **Langkah 3.3 - Pembuatan Layer Pooling 1**

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# **Langkah 3.4 - Pembuatan Layer Konvolusi 2 dan Pooling 2**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# **Langkah 3.5 - Flattening**

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# **Langkah 3.6 - Fully Connected Layer 1 (Input)**

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# **Langkah 3.7 - Fully Connected Layer 2 (Output)**

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# **Langkah 3.8 - Compile Model CNN**

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# Penggunaan loss function binary crossentropy dikarenakan kita hanya melakukan klasifikasi pada dua kelas, yaitu kucing dan anjing.
#
# ### **Langkah 4 - Fit CNN**

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 251/251 [==============================] - 3186s 13s/step - loss: 0.6819 - accuracy: 0.5773 - val_loss: 0.6368 - val_accuracy: 0.6605
# Epoch 2/25
# 251/251 [==============================] - 39s 157ms/step - loss: 0.6373 - accuracy: 0.6441 - val_loss: 0.6323 - val_accuracy: 0.6610
# Epoch 3/25
# 251/251 [==============================] - 44s 177ms/step - loss: 0.6037 - accuracy: 0.6729 - val_loss: 0.5641 - val_accuracy: 0.7130
# Epoch 4/25
# 251/251 [==============================] - 39s 154ms/step - loss: 0.5628 - accuracy: 0.7082 - val_loss: 0.5519 - val_accuracy: 0.7365
# Epoch 5/25
# 251/251 [==============================] - 39s 157ms/step - loss: 0.5373 - accuracy: 0.7248 - val_loss: 0.5589 - val_accuracy: 0.7110
# Epoch 6/25
# 251/251 [==============================] - 40s 157ms/step - loss: 0.5060 - accuracy: 0.7469 - val_loss: 0.4996 - val_accuracy: 0.7685
# Epoch 7/25
# ...

# %% [markdown]
# ### **Langkah 5 - Prediksi dengan 1 Citra**
# Pada langkah ini, kita akan mencoba melakukan prediksi pada 1 citra anjing dan kucing.

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/Colab Notebooks/aset/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'

print(prediction)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# dog
