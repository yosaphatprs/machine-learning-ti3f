# %% [markdown]
# ## **Jobsheet 11 | Pertemuan 11**
# ## **Convolutional Neural Network (CNN)**
#
# ---
#
# >### Data Mahasiswa
# ><p>Nama : Ahmad Bima Tristan Ibrahim<p>
# >Kelas : 3F<p>
# >Nim : 2141720077<p>
# >Prodi : D-IV Teknik Informatika<p>
# >Jurusan : Teknologi Informasii<p>
#
# ----
#
# ### **TUGAS**
#
# - **Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.**
# - **Buatlah model CNN untuk klasifikasi dataset MNIST.**
# ----
#
# ### **Jawab**
#
# **Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.**<p>
#
# **Lakukan Import Library**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dense, Dropout

# %% [markdown]
# **Lakukan Load Data**

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalisasikan nilai piksel menjadi antara 0 dan 1
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 16s 0us/step

# %% [markdown]
# **Sample Image**

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
       'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(train_images[i])
  # The CIFAR labels happen to be arrays,
  # which is why you need the extra index
  plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# **Lakukan pembuatan Model CNN**

# %%
# Model definition
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(10, activation='softmax'))

# Model compilation
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Model training
history = model.fit(train_images, train_labels, epochs=100,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 32s 10ms/step - loss: 3.0109 - accuracy: 0.2954 - val_loss: 2.3744 - val_accuracy: 0.4374
# Epoch 2/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.5121 - accuracy: 0.4033 - val_loss: 2.1800 - val_accuracy: 0.4937
# Epoch 3/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 2.2826 - accuracy: 0.4643 - val_loss: 2.0202 - val_accuracy: 0.5420
# Epoch 4/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 2.1118 - accuracy: 0.5019 - val_loss: 1.9272 - val_accuracy: 0.5598
# Epoch 5/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.9675 - accuracy: 0.5369 - val_loss: 1.8282 - val_accuracy: 0.5820
# Epoch 6/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.8423 - accuracy: 0.5616 - val_loss: 1.6784 - val_accuracy: 0.6065
# Epoch 7/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.7247 - accuracy: 0.5854 - val_loss: 1.5237 - val_accuracy: 0.6477
# Epoch 8/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.6216 - accuracy: 0.6050 - val_loss: 1.4999 - val_accuracy: 0.6420
# Epoch 9/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.5277 - accuracy: 0.6214 - val_loss: 1.4185 - val_accuracy: 0.6546
# Epoch 10/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.4417 - accuracy: 0.6355 - val_loss: 1.3149 - val_accuracy: 0.6738
# Epoch 11/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.3684 - accuracy: 0.6483 - val_loss: 1.3884 - val_accuracy: 0.6417
# Epoch 12/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.3064 - accuracy: 0.6613 - val_loss: 1.1705 - val_accuracy: 0.7064
# Epoch 13/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.2434 - accuracy: 0.6723 - val_loss: 1.1985 - val_accuracy: 0.6894
# Epoch 14/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.1889 - accuracy: 0.6834 - val_loss: 1.0927 - val_accuracy: 0.7152
# Epoch 15/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.1443 - accuracy: 0.6891 - val_loss: 1.0727 - val_accuracy: 0.7166
# Epoch 16/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.1035 - accuracy: 0.6977 - val_loss: 0.9907 - val_accuracy: 0.7354
# Epoch 17/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.0623 - accuracy: 0.7070 - val_loss: 0.9620 - val_accuracy: 0.7394
# Epoch 18/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.0350 - accuracy: 0.7114 - val_loss: 0.9717 - val_accuracy: 0.7324
# Epoch 19/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.9980 - accuracy: 0.7198 - val_loss: 0.9079 - val_accuracy: 0.7498
# Epoch 20/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9683 - accuracy: 0.7277 - val_loss: 0.8976 - val_accuracy: 0.7526
# Epoch 21/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.9449 - accuracy: 0.7330 - val_loss: 0.8596 - val_accuracy: 0.7616
# Epoch 22/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9233 - accuracy: 0.7367 - val_loss: 0.8857 - val_accuracy: 0.7508
# Epoch 23/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.9035 - accuracy: 0.7403 - val_loss: 0.8276 - val_accuracy: 0.7667
# Epoch 24/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.8777 - accuracy: 0.7460 - val_loss: 0.8146 - val_accuracy: 0.7711
# Epoch 25/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8631 - accuracy: 0.7490 - val_loss: 0.9169 - val_accuracy: 0.7357
# Epoch 26/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.8429 - accuracy: 0.7556 - val_loss: 0.8590 - val_accuracy: 0.7535
# Epoch 27/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8213 - accuracy: 0.7614 - val_loss: 0.7867 - val_accuracy: 0.7755
# Epoch 28/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8108 - accuracy: 0.7624 - val_loss: 0.7815 - val_accuracy: 0.7755
# Epoch 29/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.8005 - accuracy: 0.7648 - val_loss: 0.8030 - val_accuracy: 0.7661
# Epoch 30/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7832 - accuracy: 0.7678 - val_loss: 0.8228 - val_accuracy: 0.7591
# Epoch 31/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.7743 - accuracy: 0.7733 - val_loss: 0.7421 - val_accuracy: 0.7824
# Epoch 32/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.7664 - accuracy: 0.7755 - val_loss: 0.7661 - val_accuracy: 0.7807
# Epoch 33/100
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.7564 - accuracy: 0.7765 - val_loss: 0.7374 - val_accuracy: 0.7842
# Epoch 34/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7417 - accuracy: 0.7818 - val_loss: 0.7618 - val_accuracy: 0.7809
# Epoch 35/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7336 - accuracy: 0.7852 - val_loss: 0.7282 - val_accuracy: 0.7916
# Epoch 36/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.7229 - accuracy: 0.7888 - val_loss: 0.7705 - val_accuracy: 0.7750
# Epoch 37/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.7150 - accuracy: 0.7902 - val_loss: 0.7717 - val_accuracy: 0.7757
# Epoch 38/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.7085 - accuracy: 0.7904 - val_loss: 0.7229 - val_accuracy: 0.7915
# Epoch 39/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.7064 - accuracy: 0.7931 - val_loss: 0.7975 - val_accuracy: 0.7670
# Epoch 40/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.6963 - accuracy: 0.7930 - val_loss: 0.7088 - val_accuracy: 0.7947
# Epoch 41/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.6913 - accuracy: 0.7962 - val_loss: 0.6907 - val_accuracy: 0.7988
# Epoch 42/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6770 - accuracy: 0.7994 - val_loss: 0.7683 - val_accuracy: 0.7746
# Epoch 43/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6727 - accuracy: 0.8010 - val_loss: 0.6902 - val_accuracy: 0.7995
# Epoch 44/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6709 - accuracy: 0.8034 - val_loss: 0.7221 - val_accuracy: 0.7912
# Epoch 45/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6615 - accuracy: 0.8063 - val_loss: 0.7557 - val_accuracy: 0.7804
# Epoch 46/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6618 - accuracy: 0.8070 - val_loss: 0.6807 - val_accuracy: 0.8025
# Epoch 47/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6501 - accuracy: 0.8101 - val_loss: 0.6878 - val_accuracy: 0.8022
# Epoch 48/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6467 - accuracy: 0.8108 - val_loss: 0.6889 - val_accuracy: 0.8046
# Epoch 49/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6484 - accuracy: 0.8086 - val_loss: 0.7168 - val_accuracy: 0.7971
# Epoch 50/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.6408 - accuracy: 0.8138 - val_loss: 0.6957 - val_accuracy: 0.7961
# Epoch 51/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.6310 - accuracy: 0.8178 - val_loss: 0.7290 - val_accuracy: 0.7917
# Epoch 52/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6403 - accuracy: 0.8141 - val_loss: 0.7120 - val_accuracy: 0.7950
# Epoch 53/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.6320 - accuracy: 0.8160 - val_loss: 0.7276 - val_accuracy: 0.7880
# Epoch 54/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6291 - accuracy: 0.8176 - val_loss: 0.8097 - val_accuracy: 0.7646
# Epoch 55/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6245 - accuracy: 0.8181 - val_loss: 0.7015 - val_accuracy: 0.8027
# Epoch 56/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6173 - accuracy: 0.8214 - val_loss: 0.7267 - val_accuracy: 0.7899
# Epoch 57/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6176 - accuracy: 0.8214 - val_loss: 0.7314 - val_accuracy: 0.7880
# Epoch 58/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6108 - accuracy: 0.8260 - val_loss: 0.6807 - val_accuracy: 0.8115
# Epoch 59/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6059 - accuracy: 0.8250 - val_loss: 0.7299 - val_accuracy: 0.7921
# Epoch 60/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6080 - accuracy: 0.8250 - val_loss: 0.6774 - val_accuracy: 0.8091
# Epoch 61/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6002 - accuracy: 0.8278 - val_loss: 0.6694 - val_accuracy: 0.8120
# Epoch 62/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5994 - accuracy: 0.8281 - val_loss: 0.7156 - val_accuracy: 0.7949
# Epoch 63/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5974 - accuracy: 0.8274 - val_loss: 0.6882 - val_accuracy: 0.8061
# Epoch 64/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5940 - accuracy: 0.8298 - val_loss: 0.7636 - val_accuracy: 0.7821
# Epoch 65/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5874 - accuracy: 0.8312 - val_loss: 0.6789 - val_accuracy: 0.8067
# Epoch 66/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5888 - accuracy: 0.8306 - val_loss: 0.6817 - val_accuracy: 0.8107
# Epoch 67/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5855 - accuracy: 0.8337 - val_loss: 0.7109 - val_accuracy: 0.7998
# Epoch 68/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5876 - accuracy: 0.8307 - val_loss: 0.7602 - val_accuracy: 0.7837
# Epoch 69/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5839 - accuracy: 0.8353 - val_loss: 0.6945 - val_accuracy: 0.8040
# Epoch 70/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5770 - accuracy: 0.8365 - val_loss: 0.6722 - val_accuracy: 0.8103
# Epoch 71/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5809 - accuracy: 0.8356 - val_loss: 0.6784 - val_accuracy: 0.8100
# Epoch 72/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5798 - accuracy: 0.8355 - val_loss: 0.6704 - val_accuracy: 0.8121
# Epoch 73/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5827 - accuracy: 0.8343 - val_loss: 0.6835 - val_accuracy: 0.8097
# Epoch 74/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5765 - accuracy: 0.8380 - val_loss: 0.6850 - val_accuracy: 0.8086
# Epoch 75/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5685 - accuracy: 0.8392 - val_loss: 0.7377 - val_accuracy: 0.7938
# Epoch 76/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5754 - accuracy: 0.8367 - val_loss: 0.7157 - val_accuracy: 0.7974
# Epoch 77/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5657 - accuracy: 0.8407 - val_loss: 0.6645 - val_accuracy: 0.8164
# Epoch 78/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5649 - accuracy: 0.8405 - val_loss: 0.6644 - val_accuracy: 0.8162
# Epoch 79/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5688 - accuracy: 0.8407 - val_loss: 0.6934 - val_accuracy: 0.8089
# Epoch 80/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5624 - accuracy: 0.8414 - val_loss: 0.6982 - val_accuracy: 0.8039
# Epoch 81/100
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.5616 - accuracy: 0.8422 - val_loss: 0.6879 - val_accuracy: 0.8058
# Epoch 82/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5590 - accuracy: 0.8425 - val_loss: 0.6796 - val_accuracy: 0.8129
# Epoch 83/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5530 - accuracy: 0.8461 - val_loss: 0.7126 - val_accuracy: 0.8029
# Epoch 84/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5583 - accuracy: 0.8414 - val_loss: 0.7136 - val_accuracy: 0.8019
# Epoch 85/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5604 - accuracy: 0.8422 - val_loss: 0.6650 - val_accuracy: 0.8157
# Epoch 86/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5509 - accuracy: 0.8452 - val_loss: 0.6876 - val_accuracy: 0.8093
# Epoch 87/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5551 - accuracy: 0.8455 - val_loss: 0.6855 - val_accuracy: 0.8145
# Epoch 88/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5493 - accuracy: 0.8468 - val_loss: 0.6750 - val_accuracy: 0.8131
# Epoch 89/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5505 - accuracy: 0.8456 - val_loss: 0.6760 - val_accuracy: 0.8185
# Epoch 90/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5475 - accuracy: 0.8488 - val_loss: 0.6738 - val_accuracy: 0.8160
# Epoch 91/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5486 - accuracy: 0.8466 - val_loss: 0.7041 - val_accuracy: 0.8058
# Epoch 92/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5464 - accuracy: 0.8481 - val_loss: 0.6817 - val_accuracy: 0.8127
# Epoch 93/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5457 - accuracy: 0.8475 - val_loss: 0.7285 - val_accuracy: 0.8006
# Epoch 94/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5421 - accuracy: 0.8509 - val_loss: 0.7094 - val_accuracy: 0.8073
# Epoch 95/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5438 - accuracy: 0.8495 - val_loss: 0.8601 - val_accuracy: 0.7659
# Epoch 96/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5428 - accuracy: 0.8491 - val_loss: 0.6810 - val_accuracy: 0.8131
# Epoch 97/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5366 - accuracy: 0.8516 - val_loss: 0.7045 - val_accuracy: 0.8085
# Epoch 98/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5400 - accuracy: 0.8519 - val_loss: 0.6726 - val_accuracy: 0.8147
# Epoch 99/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5351 - accuracy: 0.8520 - val_loss: 0.6809 - val_accuracy: 0.8142
# Epoch 100/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5332 - accuracy: 0.8537 - val_loss: 0.6929 - val_accuracy: 0.8114

# %% [markdown]
# **Cek Arsitektur Konvolusi**

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  batch_normalization (Batch  (None, 30, 30, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 13, 13, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  batch_normalization_2 (Bat  (None, 4, 4, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization_3 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 493770 (1.88 MB)
# Trainable params: 491786 (1.88 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %% [markdown]
# **Evaluasi Model**

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.6929 - accuracy: 0.8114 - 838ms/epoch - 3ms/step

# %% [markdown]
# **Cek Hasil Akurasi**

# %%
print("Akurasi: {:.2%}".format(test_acc))
# Out:
# Akurasi: 81.14%

# %% [markdown]
# -----
#
# ### **Jawab**
#
# **Buatlah model CNN untuk klasifikasi dataset MNIST.**<p>
#
# **Lakukan Import Library**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %% [markdown]
# **Memuat dataset MNIST**

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# **Normalisasi gambar ke rentang [0, 1]**

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %% [markdown]
# **Mengonversi label ke format one-hot encoding**

# %%
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

# %% [markdown]
# **Menampilkan informasi tentang dataset**

# %%
print("Jumlah data latihan:", len(train_images))
print("Jumlah data pengujian:", len(test_images))
print("Ukuran gambar:", train_images[0].shape)
# Out:
# Jumlah data latihan: 60000
# Jumlah data pengujian: 10000
# Ukuran gambar: (28, 28)

# %% [markdown]
# **Membangun model**

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# **Mengompilasi model**

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Melatih model**

# %%
history = model.fit(train_images, train_labels, epochs=10, batch_size=128, verbose=2, validation_split=0.3)
# Out:
# Epoch 1/10
# 329/329 - 44s - loss: 0.3658 - accuracy: 0.8878 - val_loss: 0.0842 - val_accuracy: 0.9744 - 44s/epoch - 133ms/step
# Epoch 2/10
# 329/329 - 37s - loss: 0.0995 - accuracy: 0.9703 - val_loss: 0.0601 - val_accuracy: 0.9811 - 37s/epoch - 112ms/step
# Epoch 3/10
# 329/329 - 38s - loss: 0.0681 - accuracy: 0.9796 - val_loss: 0.0635 - val_accuracy: 0.9814 - 38s/epoch - 116ms/step
# Epoch 4/10
# 329/329 - 36s - loss: 0.0548 - accuracy: 0.9839 - val_loss: 0.0434 - val_accuracy: 0.9867 - 36s/epoch - 110ms/step
# Epoch 5/10
# 329/329 - 37s - loss: 0.0430 - accuracy: 0.9873 - val_loss: 0.0490 - val_accuracy: 0.9857 - 37s/epoch - 113ms/step
# Epoch 6/10
# 329/329 - 35s - loss: 0.0365 - accuracy: 0.9891 - val_loss: 0.0435 - val_accuracy: 0.9871 - 35s/epoch - 107ms/step
# Epoch 7/10
# 329/329 - 48s - loss: 0.0308 - accuracy: 0.9905 - val_loss: 0.0417 - val_accuracy: 0.9884 - 48s/epoch - 147ms/step
# Epoch 8/10
# 329/329 - 38s - loss: 0.0272 - accuracy: 0.9917 - val_loss: 0.0410 - val_accuracy: 0.9888 - 38s/epoch - 117ms/step
# Epoch 9/10
# 329/329 - 42s - loss: 0.0231 - accuracy: 0.9926 - val_loss: 0.0512 - val_accuracy: 0.9859 - 42s/epoch - 127ms/step
# Epoch 10/10
# 329/329 - 35s - loss: 0.0185 - accuracy: 0.9940 - val_loss: 0.0489 - val_accuracy: 0.9880 - 35s/epoch - 108ms/step

# %% [markdown]
# **Plot Visualisasi**

# %%
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Akurasi Pelatihan')
plt.plot(history.history['val_accuracy'], label='Akurasi Validasi')
plt.legend(loc='lower right')
plt.title('Akurasi Pelatihan dan Validasi')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss Pelatihan')
plt.plot(history.history['val_loss'], label='Loss Validasi')
plt.legend(loc='upper right')
plt.title('Loss Pelatihan dan Validasi')

plt.show()

# %% [markdown]
# **Evaluasi model pada kumpulan data uji**

# %%
validation_loss, validation_accuracy = model.evaluate(test_images, test_labels, verbose=False)
print("Loss Validasi:", validation_loss)
print("Akurasi Validasi:", validation_accuracy)
# Out:
# Loss Validasi: 0.035846225917339325
# Akurasi Validasi: 0.9904999732971191

# %% [markdown]
# **Menghasilkan nilai prediksi pada kumpulan data uji**

# %%
y_pred_enc = model.predict(test_images)
# Out:
# 313/313 [==============================] - 3s 9ms/step

# %% [markdown]
# **Mendekode nilai prediksi**

# %%
y_pred = [np.argmax(i) for i in y_pred_enc]

# %% [markdown]
# **Menampilkan laporan klasifikasi**

# %%
print(classification_report(np.argmax(test_labels, axis=1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       980
#            1       1.00      0.99      1.00      1135
#            2       0.99      1.00      0.99      1032
#            3       0.99      0.99      0.99      1010
#            4       0.99      1.00      0.99       982
#            5       0.98      0.99      0.98       892
#            6       0.99      0.98      0.99       958
#            7       0.99      0.99      0.99      1028
#            8       0.99      0.98      0.99       974
#            9       0.99      0.98      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# **Membuat matriks konfusi dan menampilkannya dengan heatmap**

# %%
fig, ax = plt.subplots(figsize=(7, 7))
sns.heatmap(confusion_matrix(np.argmax(test_labels, axis=1), y_pred), annot=True, cbar=False, fmt='1d', cmap='Greens', ax=ax)
ax.set_title('Matriks Konfusi', loc='left', fontsize=16)
ax.set_xlabel('Prediksi')
ax.set_ylabel('Aktual')
# Out:
# Text(58.222222222222214, 0.5, 'Aktual')

# %% [markdown]
# **Menampilkan target yang diprediksi pada setiap gambar**
# (label di atas gambar adalah label yang diprediksi)

# %%
plt.figure(figsize=(14, 8))
for ind, row in enumerate(test_images[:15]):
    plt.subplot(3, 5, ind+1)
    plt.title(y_pred[ind])
    img = row.reshape(28, 28)
    plt.axis('off')
    plt.imshow(img, cmap='cividis')
