# %% [markdown]
# ## Maulidio Farhan Rizkullah
# ## 2141720041
# ## 19
# ## 3F

# %% [markdown]
# ### Memodifikasi Praktikum 2

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
# Memuat dataset CIFAR-10, terdiri dari data pelatihan dan pengujian
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalisasi nilai piksel untuk berada dalam rentang 0 hingga 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
# Daftar nama kelas untuk dataset CIFAR-10
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Mengatur ukuran dan konfigurasi subplot untuk plotting gambar
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    # Menampilkan gambar pada subplot
    plt.imshow(train_images[i])

    # Menambahkan label (kelas) ke sumbu x berdasarkan indeks train_labels
    plt.xlabel(class_names[train_labels[i][0]])

# Menampilkan plot
plt.show()

# %%
model = models.Sequential() # Membuat model Sequential

# Convolution Layer
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3) , padding='same')) # Menambahkan layer convolutional 2D ke model dengan 32 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU dengan ukuran input 32 x 32 x 3 yang berupa citra RGB
# padding='same': menjaga ukuran output dari lapisan convolutional sama dengan ukuran input
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3) , padding='same')) # Menambahkan layer convolutional 2D ke model dengan 32 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU dengan ukuran input 32 x 32 x 3 yang berupa citra RGB
# padding='same': menjaga ukuran output dari lapisan convolutional sama dengan ukuran input
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional

# Pooling Layer
model.add(layers.MaxPooling2D((2, 2))) # Menambahkan layer Pooling 2D dengan tipe Max berukuran 2 x 2

# Dropout Layer
model.add(layers.Dropout(0.25)) # Menghapus sejumlah neuron dari model secara acak selama pelatihan (mencegah overfitting)

# Convolution Layer
model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3) , padding='same'))  # Menambahkan layer convolutional 2D ke model dengan 64 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional
model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3) , padding='same'))  # Menambahkan layer convolutional 2D ke model dengan 64 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional

# Pooling Layer
model.add(layers.MaxPooling2D((2, 2))) # Menambahkan layer Pooling 2D dengan tipe Max berukuran 2 x 2

# Dropout Layer
model.add(layers.Dropout(0.25)) # Menghapus sejumlah neuron dari model secara acak selama pelatihan (mencegah overfitting)

# Convolution Layer
model.add(layers.Conv2D(128, (3, 3), activation='relu', input_shape=(32, 32, 3) , padding='same'))  # Menambahkan layer convolutional 2D ke model dengan 128 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional
model.add(layers.Conv2D(128, (3, 3), activation='relu', input_shape=(32, 32, 3) , padding='same'))  # Menambahkan layer convolutional 2D ke model dengan 128 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional

# Pooling Layer
model.add(layers.MaxPooling2D((2, 2))) # Menambahkan layer Pooling 2D dengan tipe Max berukuran 2 x 2

# Dropout Layer
model.add(layers.Dropout(0.25)) # Menghapus sejumlah neuron dari model secara acak selama pelatihan (mencegah overfitting)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_12 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_13 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_14 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_15 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_16 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_17 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 4, 4, 128)         0
#
# =================================================================
# Total params: 288800 (1.10 MB)
# Trainable params: 287904 (1.10 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
# Flatten Layer
model.add(layers.Flatten()) # Menambahkan layer Flatten pada model yang digunakan untuk pemrosesan dimensi input menjadi 1 dimensi

# Full Connected Layer
model.add(layers.Dense(128, activation='relu')) # Menambah layer Dense (Full Connceted) dengan 128 neuron dan fungsi aktivasi ReLU

# Dropout Layer
model.add(layers.Dropout(0.25)) # Menghapus sejumlah neuron dari model secara acak selama pelatihan (mencegah overfitting)

# Output Layer
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_12 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_13 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_14 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_15 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_16 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_17 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 4, 4, 128)         0
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 128)               262272
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 552362 (2.11 MB)
# Trainable params: 551466 (2.10 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
# Mengompilasi model dengan optimizer 'adam', fungsi kerugian SparseCategoricalCrossentropy, dan metrik 'accuracy'
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Melatih model dengan data pelatihan dan evaluasi pada data pengujian
history = model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 [==============================] - 19s 10ms/step - loss: 1.4855 - accuracy: 0.4694 - val_loss: 1.0903 - val_accuracy: 0.6120
# Epoch 2/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.0564 - accuracy: 0.6296 - val_loss: 1.0772 - val_accuracy: 0.6276
# Epoch 3/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.8993 - accuracy: 0.6925 - val_loss: 0.8114 - val_accuracy: 0.7149
# Epoch 4/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.7922 - accuracy: 0.7294 - val_loss: 0.7860 - val_accuracy: 0.7321
# Epoch 5/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.7225 - accuracy: 0.7504 - val_loss: 0.7537 - val_accuracy: 0.7445
# Epoch 6/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6545 - accuracy: 0.7765 - val_loss: 0.5987 - val_accuracy: 0.7945
# Epoch 7/10
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6073 - accuracy: 0.7928 - val_loss: 0.6538 - val_accuracy: 0.7818
# Epoch 8/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.5671 - accuracy: 0.8074 - val_loss: 0.5841 - val_accuracy: 0.8045
# Epoch 9/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.5265 - accuracy: 0.8213 - val_loss: 0.6824 - val_accuracy: 0.7720
# Epoch 10/10
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.4968 - accuracy: 0.8292 - val_loss: 0.5472 - val_accuracy: 0.8208

# %%
# Plotting grafik akurasi selama pelatihan dan evaluasi pada data pengujian
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# Evaluasi model pada data pengujian
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.5472 - accuracy: 0.8208 - 1s/epoch - 3ms/step

# %%
print(test_acc)
# Out:
# 0.8208000063896179

# %% [markdown]
# ### Membuat model CNN untuk klasifikasi dataset MNIST

# %%
import numpy as np
import pandas as pd

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
print('The shape of the training inputs and labels:', X_train.shape, y_train.shape)
print('The shape of the testing inputs and labels:',X_test.shape, y_test.shape)
# Out:
# The shape of the training inputs and labels: (60000, 28, 28) (60000,)
# The shape of the testing inputs and labels: (10000, 28, 28) (10000,)

# %%
fig, axs = plt.subplots(3, 3)
cnt = 0
for i in range(3):
     for j in range(3):
         axs[i, j].imshow(X_train[cnt])
         cnt += 1

# %%
X_train = tf.keras.utils.normalize(X_train, axis=1)
X_test = tf.keras.utils.normalize(X_test, axis=1)

# %%
model = models.Sequential() # Membuat model Sequential

# Convolution Layer
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1) , padding='same')) # Menambahkan layer convolutional 2D ke model dengan 32 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU dengan ukuran input 32 x 32 x 3 yang berupa citra RGB
# padding='same': menjaga ukuran output dari lapisan convolutional sama dengan ukuran input
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1) , padding='same')) # Menambahkan layer convolutional 2D ke model dengan 32 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU dengan ukuran input 32 x 32 x 3 yang berupa citra RGB
# padding='same': menjaga ukuran output dari lapisan convolutional sama dengan ukuran input
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional

# Pooling Layer
model.add(layers.MaxPooling2D((2, 2))) # Menambahkan layer Pooling 2D dengan tipe Max berukuran 2 x 2

# Dropout Layer
model.add(layers.Dropout(0.25)) # Menghapus sejumlah neuron dari model secara acak selama pelatihan (mencegah overfitting)

# Convolution Layer
model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(28, 28, 1) , padding='same'))  # Menambahkan layer convolutional 2D ke model dengan 64 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional
model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(28, 28, 1) , padding='same'))  # Menambahkan layer convolutional 2D ke model dengan 64 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU
model.add(layers.BatchNormalization())

# Pooling Layer
model.add(layers.MaxPooling2D((2, 2))) # Menambahkan layer Pooling 2D dengan tipe Max berukuran 2 x 2

# Dropout Layer
model.add(layers.Dropout(0.25)) # Menghapus sejumlah neuron dari model secara acak selama pelatihan (mencegah overfitting)

# Convolution Layer
model.add(layers.Conv2D(128, (3, 3), activation='relu', input_shape=(28, 28, 1) , padding='same'))  # Menambahkan layer convolutional 2D ke model dengan 128 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional
model.add(layers.Conv2D(128, (3, 3), activation='relu', input_shape=(28, 28, 1) , padding='same'))  # Menambahkan layer convolutional 2D ke model dengan 128 filter dengan ukuran 3 x 3 dan fungsi aktivasi berupa ReLU
model.add(layers.BatchNormalization()) # Normalisasi aktivasi dari lapisan convolutional

# Pooling Layer
model.add(layers.MaxPooling2D((2, 2))) # Menambahkan layer Pooling 2D dengan tipe Max berukuran 2 x 2

# Dropout Layer
model.add(layers.Dropout(0.25)) # Menghapus sejumlah neuron dari model secara acak selama pelatihan (mencegah overfitting)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 28, 28, 32)        320
#
#  batch_normalization_24 (Ba  (None, 28, 28, 32)        128
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 28, 28, 32)        9248
#
#  batch_normalization_25 (Ba  (None, 28, 28, 32)        128
#  tchNormalization)
#
#  max_pooling2d_12 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  dropout_16 (Dropout)        (None, 14, 14, 32)        0
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 64)        18496
#
#  batch_normalization_26 (Ba  (None, 14, 14, 64)        256
#  tchNormalization)
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 64)        36928
#
#  batch_normalization_27 (Ba  (None, 14, 14, 64)        256
#  tchNormalization)
#
#  max_pooling2d_13 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  dropout_17 (Dropout)        (None, 7, 7, 64)          0
#
#  conv2d_28 (Conv2D)          (None, 7, 7, 128)         73856
#
#  batch_normalization_28 (Ba  (None, 7, 7, 128)         512
#  tchNormalization)
#
#  conv2d_29 (Conv2D)          (None, 7, 7, 128)         147584
#
#  batch_normalization_29 (Ba  (None, 7, 7, 128)         512
#  tchNormalization)
#
#  max_pooling2d_14 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  dropout_18 (Dropout)        (None, 3, 3, 128)         0
#
# =================================================================
# Total params: 288224 (1.10 MB)
# Trainable params: 287328 (1.10 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
# Flatten Layer
model.add(layers.Flatten()) # Menambahkan layer Flatten pada model yang digunakan untuk pemrosesan dimensi input menjadi 1 dimensi

# Full Connected Layer
model.add(layers.Dense(128, activation='relu')) # Menambah layer Dense (Full Connceted) dengan 128 neuron dan fungsi aktivasi ReLU

# Dropout Layer
model.add(layers.Dropout(0.25)) # Menghapus sejumlah neuron dari model secara acak selama pelatihan (mencegah overfitting)

# Output Layer
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 28, 28, 32)        320
#
#  batch_normalization_24 (Ba  (None, 28, 28, 32)        128
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 28, 28, 32)        9248
#
#  batch_normalization_25 (Ba  (None, 28, 28, 32)        128
#  tchNormalization)
#
#  max_pooling2d_12 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  dropout_16 (Dropout)        (None, 14, 14, 32)        0
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 64)        18496
#
#  batch_normalization_26 (Ba  (None, 14, 14, 64)        256
#  tchNormalization)
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 64)        36928
#
#  batch_normalization_27 (Ba  (None, 14, 14, 64)        256
#  tchNormalization)
#
#  max_pooling2d_13 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  dropout_17 (Dropout)        (None, 7, 7, 64)          0
#
#  conv2d_28 (Conv2D)          (None, 7, 7, 128)         73856
#
#  batch_normalization_28 (Ba  (None, 7, 7, 128)         512
#  tchNormalization)
#
#  conv2d_29 (Conv2D)          (None, 7, 7, 128)         147584
#
#  batch_normalization_29 (Ba  (None, 7, 7, 128)         512
#  tchNormalization)
#
#  max_pooling2d_14 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  dropout_18 (Dropout)        (None, 3, 3, 128)         0
#
#  flatten_4 (Flatten)         (None, 1152)              0
#
#  dense_8 (Dense)             (None, 128)               147584
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_9 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 437098 (1.67 MB)
# Trainable params: 436202 (1.66 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
# Mengompilasi model dengan optimizer 'adam', fungsi kerugian SparseCategoricalCrossentropy, dan metrik 'accuracy'
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Melatih model dengan data pelatihan dan evaluasi pada data pengujian
history = model.fit(X_train, y_train, epochs=12,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/12
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0222 - val_accuracy: 0.9937
# Epoch 2/12
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0216 - accuracy: 0.9938 - val_loss: 0.0202 - val_accuracy: 0.9950
# Epoch 3/12
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0212 - accuracy: 0.9941 - val_loss: 0.0231 - val_accuracy: 0.9948
# Epoch 4/12
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0180 - accuracy: 0.9947 - val_loss: 0.0218 - val_accuracy: 0.9946
# Epoch 5/12
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0161 - accuracy: 0.9952 - val_loss: 0.0277 - val_accuracy: 0.9943
# Epoch 6/12
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0172 - accuracy: 0.9953 - val_loss: 0.0234 - val_accuracy: 0.9938
# Epoch 7/12
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0156 - accuracy: 0.9956 - val_loss: 0.0271 - val_accuracy: 0.9951
# Epoch 8/12
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0152 - accuracy: 0.9957 - val_loss: 0.0211 - val_accuracy: 0.9952
# Epoch 9/12
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0142 - accuracy: 0.9960 - val_loss: 0.0259 - val_accuracy: 0.9942
# Epoch 10/12
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 0.0239 - val_accuracy: 0.9953
# Epoch 11/12
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.0266 - val_accuracy: 0.9947
# Epoch 12/12
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0124 - accuracy: 0.9964 - val_loss: 0.0280 - val_accuracy: 0.9939

# %%
# Plotting grafik akurasi selama pelatihan dan evaluasi pada data pengujian
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# Evaluasi model pada data pengujian
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.0280 - accuracy: 0.9939 - 934ms/epoch - 3ms/step

# %%
print(test_acc)
# Out:
# 0.9939000010490417

# %%
y_pred = np.argmax(model.predict(X_test), axis=-1)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
# Tentukan jumlah citra yang ingin ditampilkan
n_images = 9

# Ambil n_images citra dari data pengujian
sample_images = X_test[:n_images]
sample_labels = y_test[:n_images]

# Buat subplot untuk menampilkan citra-citra ini
plt.figure(figsize=(16, 8))
for i in range(n_images):
    plt.subplot(3, 3, i + 1)
    plt.imshow(sample_images[i].reshape(28, 28))

    plt.title(f"Test: {sample_labels[i]}\nPredicted: {y_pred[i]}",
              color='black'
              if sample_labels[i] == y_pred[i]
              else 'red')
    plt.axis('off')

plt.tight_layout()
plt.show()
